# %% [markdown]
# # Entraînement du modèle
#
# ## Préparation des données
#
# Nous allons entraîner le modèle sur notre corpus de train composé des fichiers `Europarl_train_10k.tok.true.clean.en` et `Europarl_train_10k.tok.true.clean.fr`.
#
# Les fichiers `Europarl_test_500.tok.true.clean.en` et `Europarl_test_500.tok.true.clean.fr` seront utilisés comme fichiers de validation.
#
# Les paramètres de configuration sont contenus dans le fichier `en_fr.yaml`. Avec cette configuration, nous pourrons générer les fichiers de vocabulaire nécessaires à l'entraînement du modèle : `Europarl_train_10k.vocab.src` et `Europarl_train_10k.vocab.tgt`.

# %%
# !onmt_build_vocab -config ../data/models/en_fr.yaml -n_sample 10000
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2024-05-31 00:09:19,198 INFO] Counter vocab from 10000 samples.
# [2024-05-31 00:09:19,198 INFO] Build vocab on 10000 transformed examples/corpus.
# [2024-05-31 00:09:20,537 INFO] Counters src: 11547
# [2024-05-31 00:09:20,538 INFO] Counters tgt: 14694

# %% [markdown]
# ## Entraînement du modèle

# %%
# !onmt_train -config ../data/models/en_fr.yaml
# Out:
# [2024-05-31 00:21:12,131 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2024-05-31 00:21:12,132 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2024-05-31 00:21:12,132 INFO] Missing transforms field for valid data, set to default: [].
# [2024-05-31 00:21:12,132 INFO] Parsed 2 corpora from -data.
# [2024-05-31 00:21:12,132 INFO] Get special vocabs from Transforms: {'src': [], 'tgt': []}.
# [2024-05-31 00:21:12,282 INFO] The first 10 tokens of the vocabs are:['<unk>', '<blank>', '<s>', '</s>', 'the', ',', '.', 'of', 'to', 'and']
# [2024-05-31 00:21:12,283 INFO] The decoder start token is: <s>
# [2024-05-31 00:21:12,283 INFO] Building model...
# [2024-05-31 00:21:14,085 INFO] Switching model to float32 for amp/apex_amp
# [2024-05-31 00:21:14,085 INFO] Non quantized layer compute is fp32
# [2024-05-31 00:21:14,093 INFO] NMTModel(
#   (encoder): RNNEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
# ...

# %% [markdown]
# ### Traduction

# %% [markdown]
# Nous pouvons maintenant lancer la traduction grâce au modèle que nous avons entraîné. Cependant, du fait des capacités limitées de nos machines, nous n'avons pu entraîner le modèle que sur une quantité restreinte de données et la traduction a de fortes chances d'être assez mauvaise.

# %%
# !onmt_translate -model ../data/run1/model1_step_1000.pt -src ../data/clean/europarl/Europarl_test_500.tok.true.clean.en -output ../data/clean/europarl/Europarl_pred_500.tok.true.clean.en -gpu 0 -verbose
